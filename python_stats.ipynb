# %%
import csv
import statistics
import time
from collections import defaultdict, Counter

# === Start Timer ===
start = time.time()

# === Utility Functions ===
def load_data(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        return list(csv.DictReader(f))

def is_number(s):
    try: float(s); return True
    except: return False

def get_numeric_columns(data):
    return [col for col in data[0] if all(is_number(row[col]) or row[col]=='' for row in data[:100])]

def compute_stats(data, column):
    values = [float(row[column]) for row in data if is_number(row[column])]
    if not values:
        return {
            'count': 0,
            'mean': None,
            'min': None,
            'max': None,
            'std': None
        }
    return {
        'count': len(values),
        'mean': round(statistics.mean(values), 2),
        'min': min(values),
        'max': max(values),
        'std': round(statistics.stdev(values), 2) if len(values) > 1 else 0
    }

def compute_categorical_stats(data, column):
    values = [row[column] for row in data if row[column]]
    freq = Counter(values)
    return {
        'count': len(values),
        'unique': len(set(values)),
        'most_common': freq.most_common(1)[0] if freq else None
    }

def group_by(data, keys):
    grouped = defaultdict(list)
    for row in data:
        if all(k in row for k in keys):
            key = tuple(row[k] for k in keys)
            grouped[key].append(row)
    return grouped

# === Main Analysis ===

name = "Syracuse Men's Basketball"
path = "C:/Users/SHUBHAM/Downloads/period_03/syracuse_mens_basketball_stats.csv"

print(f"\n\n📊 === Analyzing {name} ===")
data = load_data(path)
numeric_cols = get_numeric_columns(data)

# === Overall Stats ===
print("\n=== Overall Stats ===")
for col in data[0]:
    print(f"\n{col}:")
    if col in numeric_cols:
        print(compute_stats(data, col))
    else:
        print(compute_categorical_stats(data, col))

# === Grouped Stats by Player ===
print("\n=== Grouped by Player ===")
groups = list(group_by(data, ['Player']).items())
print(f"📌 Total players: {len(groups)}")

for key, rows in groups[:3]:  # Show 3 example players
    print(f"\nPlayer: {key[0]}")
    for col in numeric_cols:
        print(f"  {col}:", compute_stats(rows, col))

# === End Timer ===
end = time.time()
print(f"\n⏱️ Script completed in {round(end - start, 2)} seconds.")
# Out:
# 📊 === Analyzing Syracuse Men's Basketball ===
#
# === Overall Stats ===
#
# #:
# {'count': 32, 'mean': 14.25, 'min': 0.0, 'max': 51.0, 'std': 15.47}
#
# Player:
# {'count': 32, 'unique': 16, 'most_common': ('Starling, J.J.', 2)}
#
# GP-GS:
# {'count': 32, 'unique': 23, 'most_common': ('1-0', 5)}
#
# MIN:
# {'count': 32, 'mean': 339.06, 'min': 1.0, 'max': 987.0, 'std': 321.16}
#
# AVG:
# {'count': 32, 'mean': 15.23, 'min': 0.5, 'max': 34.6, 'std': 11.65}
#
# FG-FGA:
# {'count': 32, 'unique': 24, 'most_common': ('0-0', 8)}
#
# FG%:
# {'count': 32, 'mean': 0.33, 'min': 0.0, 'max': 0.826, 'std': 0.25}
#
# 3FG-FGA:
# {'count': 32, 'unique': 22, 'most_common': ('0-0', 10)}
#
# 3FG%:
# {'count': 32, 'mean': 0.21, 'min': 0.0, 'max': 0.462, 'std': 0.18}
#
# FT-FTA:
# {'count': 32, 'unique': 24, 'most_common': ('0-0', 8)}
#
# FT%:
# {'count': 32, 'mean': 0.56, 'min': 0.0, 'max': 1.0, 'std': 0.35}
#
# OFF:
# {'count': 32, 'mean': 14.88, 'min': 0.0, 'max': 114.0, 'std': 24.08}
#
# DEF:
# {'count': 32, 'mean': 40.34, 'min': 0.0, 'max': 203.0, 'std': 47.68}
#
# TOT:
# {'count': 32, 'mean': 55.22, 'min': 0.0, 'max': 317.0, 'std': 70.3}
#
# AVG_RB:
# {'count': 32, 'mean': 2.56, 'min': 0.0, 'max': 10.8, 'std': 2.95}
#
# PF:
# {'count': 32, 'mean': 27.69, 'min': 0.0, 'max': 81.0, 'std': 25.58}
#
# DQ:
# {'count': 32, 'mean': 0.41, 'min': 0.0, 'max': 4.0, 'std': 0.87}
#
# A:
# {'count': 32, 'mean': 22.25, 'min': 0.0, 'max': 134.0, 'std': 30.32}
#
# TO:
# {'count': 32, 'mean': 20.12, 'min': 0.0, 'max': 72.0, 'std': 20.6}
#
# BLK:
# {'count': 32, 'mean': 4.06, 'min': 0.0, 'max': 16.0, 'std': 4.6}
#
# STL:
# {'count': 32, 'mean': 8.03, 'min': 0.0, 'max': 36.0, 'std': 8.96}
#
# PTS:
# {'count': 32, 'mean': 123.28, 'min': 0.0, 'max': 463.0, 'std': 127.78}
#
# AVG_PTS:
# {'count': 32, 'mean': 5.68, 'min': 0.0, 'max': 17.8, 'std': 5.31}
#
# === Grouped by Player ===
# 📌 Total players: 16
#
# Player: Starling, J.J.
#   #: {'count': 2, 'mean': 2.0, 'min': 2.0, 'max': 2.0, 'std': 0.0}
#   MIN: {'count': 2, 'mean': 754.0, 'min': 608.0, 'max': 900.0, 'std': 206.48}
#   AVG: {'count': 2, 'mean': 34.2, 'min': 33.8, 'max': 34.6, 'std': 0.57}
#   FG%: {'count': 2, 'mean': 0.39, 'min': 0.381, 'max': 0.407, 'std': 0.02}
#   3FG%: {'count': 2, 'mean': 0.26, 'min': 0.255, 'max': 0.268, 'std': 0.01}
#   FT%: {'count': 2, 'mean': 0.71, 'min': 0.685, 'max': 0.735, 'std': 0.04}
#   OFF: {'count': 2, 'mean': 17.0, 'min': 15.0, 'max': 19.0, 'std': 2.83}
#   DEF: {'count': 2, 'mean': 63.0, 'min': 47.0, 'max': 79.0, 'std': 22.63}
#   TOT: {'count': 2, 'mean': 80.0, 'min': 62.0, 'max': 98.0, 'std': 25.46}
#   AVG_RB: {'count': 2, 'mean': 3.6, 'min': 3.4, 'max': 3.8, 'std': 0.28}
#   PF: {'count': 2, 'mean': 42.5, 'min': 34.0, 'max': 51.0, 'std': 12.02}
#   DQ: {'count': 2, 'mean': 0.5, 'min': 0.0, 'max': 1.0, 'std': 0.71}
#   A: {'count': 2, 'mean': 62.5, 'min': 52.0, 'max': 73.0, 'std': 14.85}
#   TO: {'count': 2, 'mean': 51.0, 'min': 41.0, 'max': 61.0, 'std': 14.14}
#   BLK: {'count': 2, 'mean': 6.5, 'min': 5.0, 'max': 8.0, 'std': 2.12}
#   STL: {'count': 2, 'mean': 19.5, 'min': 16.0, 'max': 23.0, 'std': 4.95}
#   PTS: {'count': 2, 'mean': 382.0, 'min': 301.0, 'max': 463.0, 'std': 114.55}
#   AVG_PTS: {'count': 2, 'mean': 17.25, 'min': 16.7, 'max': 17.8, 'std': 0.78}
#
# Player: Freeman, Donnie
#   #: {'count': 2, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'std': 0.0}
#   MIN: {'count': 2, 'mean': 219.5, 'min': 84.0, 'max': 355.0, 'std': 191.63}
#   AVG: {'count': 2, 'mean': 26.7, 'min': 25.4, 'max': 28.0, 'std': 1.84}
#   FG%: {'count': 2, 'mean': 0.51, 'min': 0.504, 'max': 0.519, 'std': 0.01}
#   3FG%: {'count': 2, 'mean': 0.27, 'min': 0.2, 'max': 0.333, 'std': 0.09}
#   FT%: {'count': 2, 'mean': 0.77, 'min': 0.737, 'max': 0.796, 'std': 0.04}
#   OFF: {'count': 2, 'mean': 8.5, 'min': 2.0, 'max': 15.0, 'std': 9.19}
#   DEF: {'count': 2, 'mean': 59.5, 'min': 23.0, 'max': 96.0, 'std': 51.62}
#   TOT: {'count': 2, 'mean': 68.0, 'min': 25.0, 'max': 111.0, 'std': 60.81}
#   AVG_RB: {'count': 2, 'mean': 8.1, 'min': 7.9, 'max': 8.3, 'std': 0.28}
#   PF: {'count': 2, 'mean': 15.5, 'min': 7.0, 'max': 24.0, 'std': 12.02}
#   DQ: {'count': 2, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   A: {'count': 2, 'mean': 10.5, 'min': 2.0, 'max': 19.0, 'std': 12.02}
#   TO: {'count': 2, 'mean': 14.0, 'min': 3.0, 'max': 25.0, 'std': 15.56}
#   BLK: {'count': 2, 'mean': 3.0, 'min': 1.0, 'max': 5.0, 'std': 2.83}
#   STL: {'count': 2, 'mean': 3.5, 'min': 2.0, 'max': 5.0, 'std': 2.12}
#   PTS: {'count': 2, 'mean': 115.0, 'min': 43.0, 'max': 187.0, 'std': 101.82}
#   AVG_PTS: {'count': 2, 'mean': 13.85, 'min': 13.4, 'max': 14.3, 'std': 0.64}
#
# Player: Lampkin Jr., Eddie
#   #: {'count': 2, 'mean': 44.0, 'min': 44.0, 'max': 44.0, 'std': 0.0}
#   MIN: {'count': 2, 'mean': 803.0, 'min': 619.0, 'max': 987.0, 'std': 260.22}
#   AVG: {'count': 2, 'mean': 30.45, 'min': 29.9, 'max': 31.0, 'std': 0.78}
#   FG%: {'count': 2, 'mean': 0.59, 'min': 0.594, 'max': 0.596, 'std': 0.0}
#   3FG%: {'count': 2, 'mean': 0.2, 'min': 0.0, 'max': 0.4, 'std': 0.28}
#   FT%: {'count': 2, 'mean': 0.67, 'min': 0.641, 'max': 0.69, 'std': 0.03}
#   OFF: {'count': 2, 'mean': 92.0, 'min': 70.0, 'max': 114.0, 'std': 31.11}
#   DEF: {'count': 2, 'mean': 174.5, 'min': 146.0, 'max': 203.0, 'std': 40.31}
#   TOT: {'count': 2, 'mean': 266.5, 'min': 216.0, 'max': 317.0, 'std': 71.42}
#   AVG_RB: {'count': 2, 'mean': 10.2, 'min': 9.6, 'max': 10.8, 'std': 0.85}
#   PF: {'count': 2, 'mean': 63.5, 'min': 52.0, 'max': 75.0, 'std': 16.26}
#   DQ: {'count': 2, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'std': 0.0}
#   A: {'count': 2, 'mean': 54.5, 'min': 39.0, 'max': 70.0, 'std': 21.92}
#   TO: {'count': 2, 'mean': 57.0, 'min': 42.0, 'max': 72.0, 'std': 21.21}
#   BLK: {'count': 2, 'mean': 13.5, 'min': 11.0, 'max': 16.0, 'std': 3.54}
#   STL: {'count': 2, 'mean': 10.5, 'min': 7.0, 'max': 14.0, 'std': 4.95}
#   PTS: {'count': 2, 'mean': 308.5, 'min': 239.0, 'max': 378.0, 'std': 98.29}
#   AVG_PTS: {'count': 2, 'mean': 11.75, 'min': 11.5, 'max': 12.0, 'std': 0.35}
#
# ⏱️ Script completed in 0.01 seconds.
